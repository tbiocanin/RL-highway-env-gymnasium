# %%
import gymnasium as gym
import torch
from stable_baselines3 import PPO

# %%
env = gym.make('highway-v0', render_mode='rgb_array')
model = PPO(
  policy='MlpPolicy',
  policy_kwargs=dict(layers=[256, 256]),
  env=env,
  batch_size=64,
  verbose=2,
  learning_rate=5e-4,
  tensorboard_log="highway_ppo/"
)

model.learn(1000)
model.save("highway_ppo/model")

# Load and test saved model
model = PPO.load("highway_ppo/model")
while True:
  done = truncated = False
  obs, info = env.reset()
  while not (done or truncated):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env.step(action)
    env.render()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_ppo/PPO_6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.2     |
# |    ep_rew_mean     | 11.5     |
# | time/              |          |
# |    fps             | 3        |
# |    iterations      | 1        |
# |    time_elapsed    | 599      |
# |    total_timesteps | 2048     |
# ---------------------------------
# [[ 1.          0.8954749   0.5         0.3125      0.        ]
#  [ 1.          0.11697573  0.25       -0.01550291  0.        ]
#  [ 1.          0.22981548  0.25       -0.03317747  0.        ]
#  [ 1.          0.33368385 -0.5        -0.047234    0.        ]
#  [ 1.          0.44736075 -0.25       -0.03077859  0.        ]]
# [[ 1.          0.90390974  0.5         0.3125      0.        ]
#  [ 1.          0.10289572  0.         -0.02399689  0.        ]
#  [ 1.          0.21218121  0.         -0.02541734  0.        ]
#  [ 1.          0.3214939  -0.25       -0.03818425  0.        ]
#  [ 1.          0.43324235 -0.25       -0.04277527  0.        ]]
# [[ 1.          0.9120758   0.5         0.3125      0.        ]
#  [ 1.          0.1092547   0.25       -0.03025085  0.        ]
#  [ 1.          0.21951841  0.         -0.01371336  0.        ]
#  [ 1.          0.31802115 -0.25       -0.01983843  0.        ]
#  [ 1.          0.42951944 -0.25       -0.04113258  0.        ]]
# [[ 1.          0.91153586  0.          0.3125      0.        ]
#  [ 1.          0.10679694  0.5        -0.0429602   0.        ]
#  [ 1.          0.21819134  0.5        -0.03787554  0.        ]
#  [ 1.          0.31933352  0.75       -0.04221424  0.        ]
#  [ 1.          0.41868114  0.5        -0.0143509   0.        ]]
# [[ 1.          0.8919224   0.5         0.3125      0.        ]
#  [ 1.          0.10478025  0.25       -0.02037525  0.        ]
#  [ 1.          0.21860842 -0.25       -0.0149181   0.        ]
#  [ 1.          0.32558987 -0.5        -0.04342779  0.        ]
#  [ 1.          0.4301882   0.         -0.04382806  0.        ]]
# [[ 1.          0.91588634  0.5         0.3125      0.        ]
#  [ 1.          0.1070772   0.         -0.02936888  0.        ]
#  [ 1.          0.20038328 -0.5        -0.04039151  0.        ]
#  [ 1.          0.31517953  0.         -0.01282177  0.        ]
#  [ 1.          0.41595912  0.25       -0.02277867  0.        ]]
# [[ 1.          0.9032062   0.5         0.3125      0.        ]
#  [ 1.          0.09826731  0.25       -0.03682464  0.        ]
#  [ 1.          0.19802354  0.         -0.02503891  0.        ]
#  [ 1.          0.29527536  0.25       -0.02722498  0.        ]
#  [ 1.          0.39709753 -0.25       -0.02690737  0.        ]]
# [[ 1.          0.91027164  0.5         0.3125      0.        ]
#  [ 1.          0.11077196 -0.5        -0.04425282  0.        ]
#  [ 1.          0.21809576  0.25       -0.01691337  0.        ]
#  [ 1.          0.32223657 -0.25       -0.02632979  0.        ]
#  [ 1.          0.4199314   0.25       -0.02036349  0.        ]]
# [[ 1.          0.88880473  0.5         0.3125      0.        ]
#  [ 1.          0.09842364 -0.5        -0.01930494  0.        ]
#  [ 1.          0.1956829   0.         -0.0412144   0.        ]
#  [ 1.          0.30459127  0.         -0.0452445   0.        ]
#  [ 1.          0.40002385  0.         -0.03884508  0.        ]]
# [[ 1.          0.88303417  0.          0.3125      0.        ]
#  [ 1.          0.11030035  0.         -0.02328457  0.        ]
#  [ 1.          0.22759703  0.25       -0.01670213  0.        ]
#  [ 1.          0.32696795  0.         -0.02230758  0.        ]
#  [ 1.          0.42913976  0.         -0.02548291  0.        ]]
# [[ 1.          0.9142087   0.25        0.3125      0.        ]
#  [ 1.          0.09765572 -0.25       -0.01855286  0.        ]
#  [ 1.          0.21065111  0.5        -0.03908288  0.        ]
#  [ 1.          0.31366763  0.         -0.03562891  0.        ]
#  [ 1.          0.41898054  0.25       -0.03410486  0.        ]]
# [[ 1.          0.9019121   0.          0.3125      0.        ]
#  [ 1.          0.10305047  0.75       -0.04684489  0.        ]
#  [ 1.          0.21327296  0.5        -0.03754376  0.        ]
#  [ 1.          0.3230316   0.75       -0.04366491  0.        ]
#  [ 1.          0.43145442  0.75       -0.03593144  0.        ]]
# [[ 1.          0.8831528   0.25        0.3125      0.        ]
#  [ 1.          0.10133605  0.25       -0.0211434   0.        ]
#  [ 1.          0.21145712  0.25       -0.03423287  0.        ]
#  [ 1.          0.30832627  0.         -0.02383988  0.        ]
#  [ 1.          0.42346442 -0.25       -0.02341966  0.        ]]
# [[ 1.          0.9173656   0.75        0.3125      0.        ]
#  [ 1.          0.10587659 -0.25       -0.0171535   0.        ]
#  [ 1.          0.21633466 -0.25       -0.04567338  0.        ]
#  [ 1.          0.31157187 -0.5        -0.03363524  0.        ]
#  [ 1.          0.4229354  -0.25       -0.04308757  0.        ]]
# [[ 1.          0.89009744  0.25        0.3125      0.        ]
#  [ 1.          0.10135403  0.25       -0.01954039  0.        ]
#  [ 1.          0.19952911 -0.25       -0.02967487  0.        ]
#  [ 1.          0.30617982  0.         -0.02215879  0.        ]
#  [ 1.          0.42515075  0.         -0.01255212  0.        ]]
# [[ 1.          0.8799354   0.25        0.3125      0.        ]
#  [ 1.          0.11383093  0.25       -0.01260204  0.        ]
#  [ 1.          0.21256548  0.25       -0.02622649  0.        ]
#  [ 1.          0.31885067  0.         -0.02873679  0.        ]
#  [ 1.          0.4210228   0.25       -0.03219128  0.        ]]
# [[ 1.          0.91216177  0.25        0.3125      0.        ]
#  [ 1.          0.10998333  0.         -0.0430496   0.        ]
#  [ 1.          0.20730472  0.         -0.02507935  0.        ]
#  [ 1.          0.31093448  0.5        -0.02927131  0.        ]
#  [ 1.          0.42676324 -0.25       -0.01974966  0.        ]]
# [[ 1.          0.8889489   0.5         0.3125      0.        ]
#  [ 1.          0.10637077  0.25       -0.02683937  0.        ]
#  [ 1.          0.20628922  0.25       -0.04409194  0.        ]
#  [ 1.          0.3027561   0.         -0.04022491  0.        ]
#  [ 1.          0.39837936  0.         -0.03054283  0.        ]]
# [[ 1.          0.9123304   0.          0.3125      0.        ]
#  [ 1.          0.10107963  0.5        -0.04702052  0.        ]
#  [ 1.          0.20935255  0.75       -0.0254883   0.        ]
#  [ 1.          0.32013127  0.5        -0.02838325  0.        ]
#  [ 1.          0.41439405  0.25       -0.03911062  0.        ]]
# [[ 1.          0.88832253  0.          0.3125      0.        ]
#  [ 1.          0.09703299  0.75       -0.04988888  0.        ]
#  [ 1.          0.2052676   0.75       -0.0443473   0.        ]
#  [ 1.          0.30755943  0.         -0.04116034  0.        ]
#  [ 1.          0.40291852  0.5        -0.03466353  0.        ]]
# [[ 1.          0.8800044   0.5         0.3125      0.        ]
#  [ 1.          0.11050818  0.25       -0.04545049  0.        ]
#  [ 1.          0.20928498 -0.5        -0.04298129  0.        ]
#  [ 1.          0.31403983 -0.25       -0.04269794  0.        ]
#  [ 1.          0.41800812  0.25       -0.03909784  0.        ]]
# [[ 1.          0.9000395   0.5         0.3125      0.        ]
#  [ 1.          0.10167351  0.         -0.0144547   0.        ]
#  [ 1.          0.2008627  -0.25       -0.03247087  0.        ]
#  [ 1.          0.30901378 -0.25       -0.01327475  0.        ]
#  [ 1.          0.415756   -0.5        -0.03548965  0.        ]]
# [[ 1.          0.88218325  0.          0.3125      0.        ]
#  [ 1.          0.0955544   0.5        -0.04849583  0.        ]
#  [ 1.          0.19931833  0.75       -0.02081689  0.        ]
#  [ 1.          0.2999771   0.25       -0.04367438  0.        ]
#  [ 1.          0.40061238  0.25       -0.03627139  0.        ]]
# [[ 1.          0.88681877  0.          0.3125      0.        ]
#  [ 1.          0.11124431  0.25       -0.0303588   0.        ]
#  [ 1.          0.21874437  0.5        -0.04676608  0.        ]
#  [ 1.          0.3119335   0.5        -0.04938349  0.        ]
#  [ 1.          0.41711786  0.5        -0.02025955  0.        ]]
# [[ 1.          0.89265853  0.75        0.3125      0.        ]
#  [ 1.          0.10222266 -0.25       -0.0302348   0.        ]
#  [ 1.          0.19543524 -0.75       -0.03915878  0.        ]
#  [ 1.          0.30957937  0.         -0.03424665  0.        ]
#  [ 1.          0.40879455 -0.5        -0.0327675   0.        ]]
# [[ 1.          0.9108367   0.5         0.3125      0.        ]
#  [ 1.          0.11401239 -0.25       -0.01276854  0.        ]
#  [ 1.          0.22242959  0.25       -0.03130744  0.        ]
#  [ 1.          0.32003447  0.         -0.02885883  0.        ]
#  [ 1.          0.42670915 -0.5        -0.04330386  0.        ]]
# [[ 1.          0.8842984   0.5         0.3125      0.        ]
#  [ 1.          0.11078458  0.         -0.01984801  0.        ]
#  [ 1.          0.21686427  0.         -0.01771067  0.        ]
#  [ 1.          0.32902056  0.25       -0.03387389  0.        ]
#  [ 1.          0.4307529   0.25       -0.01655504  0.        ]]
# [[ 1.          0.886423    0.          0.3125      0.        ]
#  [ 1.          0.09473015  0.5        -0.04880965  0.        ]
#  [ 1.          0.20290029  0.25       -0.0228035   0.        ]
#  [ 1.          0.31603047  0.         -0.0379902   0.        ]
#  [ 1.          0.4247688   0.5        -0.0426199   0.        ]]
# [[ 1.          0.90532625  0.5         0.3125      0.        ]
#  [ 1.          0.10739181 -0.25       -0.02674306  0.        ]
#  [ 1.          0.20647365  0.25       -0.0391175   0.        ]
#  [ 1.          0.31127027 -0.25       -0.01492438  0.        ]
#  [ 1.          0.40550363 -0.5        -0.03765962  0.        ]]
# [[ 1.          0.9158306   0.25        0.3125      0.        ]
#  [ 1.          0.09716211 -0.25       -0.03901622  0.        ]
#  [ 1.          0.2039008  -0.25       -0.04167573  0.        ]
#  [ 1.          0.3148039   0.5        -0.03244319  0.        ]
#  [ 1.          0.42034423 -0.25       -0.03620727  0.        ]]
# [[ 1.          0.90127176  0.          0.3125      0.        ]
#  [ 1.          0.09762787  0.25       -0.02863125  0.        ]
#  [ 1.          0.20283702  0.25       -0.04725739  0.        ]
#  [ 1.          0.29945615  0.25       -0.04502126  0.        ]
#  [ 1.          0.40298057  0.75       -0.02485705  0.        ]]
# [[ 1.          0.8780307   0.75        0.3125      0.        ]
#  [ 1.          0.110148   -0.75       -0.03338867  0.        ]
#  [ 1.          0.2137023  -0.75       -0.04611798  0.        ]
#  [ 1.          0.32411954  0.         -0.03883428  0.        ]
#  [ 1.          0.42211413 -0.75       -0.0393185   0.        ]]
# [[ 1.          0.9166525   0.          0.3125      0.        ]
#  [ 1.          0.1048622   0.25       -0.04960493  0.        ]
#  [ 1.          0.20500119  0.75       -0.04409734  0.        ]
#  [ 1.          0.31218332  0.75       -0.02818657  0.        ]
#  [ 1.          0.41404268  0.25       -0.01547611  0.        ]]
# [[ 1.          0.89011467  0.25        0.3125      0.        ]
#  [ 1.          0.11175518  0.5        -0.04219915  0.        ]
#  [ 1.          0.20781769  0.5        -0.04633169  0.        ]
#  [ 1.          0.3132955  -0.25       -0.04695611  0.        ]
#  [ 1.          0.4223376   0.25       -0.01961922  0.        ]]
# [[ 1.          0.9082171   0.          0.3125      0.        ]
#  [ 1.          0.09417845  0.75       -0.04686898  0.        ]
#  [ 1.          0.19609952  0.75       -0.02681794  0.        ]
#  [ 1.          0.29202238  0.         -0.04129806  0.        ]
#  [ 1.          0.40159455  0.75       -0.045034    0.        ]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 21
#      19 while not (done or truncated):
#      20   action, _states = model.predict(obs, deterministic=True)
# ---> 21   obs, reward, done, truncated, info = env.step(action)
#      22   env.render()
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/.local/lib/python3.8/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File ~/.local/lib/python3.8/site-packages/highway_env/envs/common/abstract.py:235, in AbstractEnv.step(self, action)
#     232     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     234 self.time += 1 / self.config["policy_frequency"]
# --> 235 self._simulate(action)
#     237 obs = self.observation_type.observe()
#     238 reward = self._reward(action)
#
# File ~/.local/lib/python3.8/site-packages/highway_env/envs/common/abstract.py:257, in AbstractEnv._simulate(self, action)
#     252 if action is not None \
#     253         and not self.config["manual_control"] \
#     254         and self.steps % int(self.config["simulation_frequency"] // self.config["policy_frequency"]) == 0:
#     255     self.action_type.act(action)
# --> 257 self.road.act()
#     258 self.road.step(1 / self.config["simulation_frequency"])
#     259 self.steps += 1
#
# File ~/.local/lib/python3.8/site-packages/highway_env/road/road.py:324, in Road.act(self)
#     322 """Decide the actions of each entity on the road."""
#     323 for vehicle in self.vehicles:
# --> 324     vehicle.act()
#
# File ~/.local/lib/python3.8/site-packages/highway_env/vehicle/behavior.py:112, in IDMVehicle.act(self, action)
#     110     action['acceleration'] = min(action['acceleration'], target_idm_acceleration)
#     111 # action['acceleration'] = self.recover_from_stop(action['acceleration'])
# --> 112 action['acceleration'] = np.clip(action['acceleration'], -self.ACC_MAX, self.ACC_MAX)
#     113 Vehicle.act(self, action)
#
# File <__array_function__ internals>:200, in clip(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2180, in clip(a, a_min, a_max, out, **kwargs)
#    2111 @array_function_dispatch(_clip_dispatcher)
#    2112 def clip(a, a_min, a_max, out=None, **kwargs):
#    2113     """
#    2114     Clip (limit) the values in an array.
#    2115
#    (...)
#    2178
#    2179     """
# -> 2180     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/_methods.py:139, in _clip(a, min, max, out, casting, **kwargs)
#     137     min = -float('inf')
#     138     using_deprecated_nan = True
# --> 139 if _clip_dep_is_scalar_nan(max):
#     140     max = float('inf')
#     141     using_deprecated_nan = True
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/_methods.py:95, in _clip_dep_is_scalar_nan(a)
#      93 def _clip_dep_is_scalar_nan(a):
#      94     # guarded to protect circular imports
# ---> 95     from numpy.core.fromnumeric import ndim
#      96     if ndim(a) != 0:
#      97         return False
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
